# %%
import os

from time import sleep
import config

from nat_tv_ratings import get_nat_tv_reports
from create_dicts import update_tv_index_dicts, update_nat_tv_ad_dict
from google_connector import append_ads_to_google


start_date = '2025-03-30' 
end_date = '2025-03-30' #- ВКЛЮЧИТЕЛЬНО

flag='regular' #first / regular
# Out:
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314

# %%
# Если флаг first - создаем набор пустых таблиц-справочников / 
# забираем статистику / заполняем таблицы фактов и справочник nat_tv_ad_dict
# Если флаг regular - то грузим статистику и обновляем справочники
# если start_date(дата начала) НЕ указана, то 
# удаляем из БД - последние 17(сегодня-14-3) дней
# перезаисываем статистику за этот период
# если НЕ указана end_date(дата окончания) - ВКЛЮЧИТЕЛЬНО, то грузим данные до сегодня-3 дня
# получаем статистику по отчету Simple и Buying
get_nat_tv_reports(start_date=start_date, end_date=end_date, flag=flag)
# get_nat_tv_reports(flag=flag)
# Обновляем все справочники из ТВ Индекс
update_tv_index_dicts()
# Обновляем основной справочник объявлений
update_nat_tv_ad_dict()

# загружаем в гугл докс Чистка список объяалений с флагом=2
append_ads_to_google()
# Out:
# Скрипт запущен 2025-04-07 17:45:53.716783
# **************************************************
# Забираем из БД НЕ ОБНОВЛЕННЫЙ справочник объявлений
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
#
# Загружаем отчет за период 2025-03-30 - 2025-03-30. Общее количество дней: 1
# **************************************************
#
#
# ==========Загружаем 2025-03-30. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 671ee510-f4c9-4463-b847-73229036d69f) [= = = = = = = = ] время расчета: 0:00:25.503817
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 17:46:25.542331
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-04-07 17:46:25.612325
# Время выполнения задачи: 0:00:00.069994
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (9) [ = = = ] время расчета: 0:00:16.041755
# Расчет завершен, получаем результат
# Собираем таблицу
# .........Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 17:47:06.006988
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-04-07 17:47:06.026829
# Время выполнения задачи: 0:00:00.019841
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 17:47:06.055822
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-04-07 17:47:06.569157
# Время выполнения задачи: 0:00:00.513335
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# **************************************************
# Время окончания работы скрипта 2025-04-07 17:47:06.569157
# Период загрузки 2025-03-30 - 2025-03-30. Общее время работы скрипта: 0:01:12.852374
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 1
# Всего найдено записей: 1
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 17:47:06.729151
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_advertiser_list_dict
# Скрипт отработал 2025-04-07 17:47:06.739151
# Время выполнения задачи: 0:00:00.010000
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 4
# Всего найдено записей: 4
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 17:47:06.865300
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_brand_list_dict
# Скрипт отработал 2025-04-07 17:47:06.879305
# Время выполнения задачи: 0:00:00.014005
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 1
# Всего найдено записей: 1
#
# Запрошены записи: 0 - 4
# Всего найдено записей: 4
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 17:47:07.068952
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_subbrand_list_dict
# Скрипт отработал 2025-04-07 17:47:07.081750
# Время выполнения задачи: 0:00:00.012798
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 6
# Всего найдено записей: 6
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 17:47:07.204396
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_model_list_dict
# Скрипт отработал 2025-04-07 17:47:07.217400
# Время выполнения задачи: 0:00:00.013004
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 5
# Всего найдено записей: 5
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 17:47:07.403951
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_article_list3_dict
# Скрипт отработал 2025-04-07 17:47:07.413951
# Время выполнения задачи: 0:00:00.010000
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 5
# Всего найдено записей: 5
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 17:47:07.520786
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_article_list4_dict
# Скрипт отработал 2025-04-07 17:47:07.538443
# Время выполнения задачи: 0:00:00.017657
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 1
# Всего найдено записей: 1
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 17:47:07.653533
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_audio_slogan_dict
# Скрипт отработал 2025-04-07 17:47:07.665525
# Время выполнения задачи: 0:00:00.011992
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 1
# Всего найдено записей: 1
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 17:47:07.802435
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_video_slogan_dict
# Скрипт отработал 2025-04-07 17:47:07.814438
# Время выполнения задачи: 0:00:00.012003
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
# C:\Users\o.bogomolov\Desktop\Jupyter_notebook\42_02_mediascope_costs_n_ratings\create_dicts.py:71: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(full_cleaning_link, header=None, usecols=cols_count)
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: nat_tv_ad_dict успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица nat_tv_ad_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 17:47:26.518890
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-04-07 17:47:26.564437
# Время выполнения задачи: 0:00:00.045547
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Connection established successfully...
# DataFrame exported successfully...
