# %%
import os

from time import sleep
import config

from nat_tv_ratings import get_nat_tv_reports
from create_dicts import update_tv_index_dicts, update_nat_tv_ad_dict
from google_connector import append_ads_to_google


start_date = '2025-03-25'
end_date = '2025-03-27' #- ВКЛЮЧИТЕЛЬНО

flag='regular' #first / regular
# Out:
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314

# %%
# Если флаг first - создаем набор пустых таблиц-справочников / 
# забираем статистику / заполняем таблицы фактов и справочник nat_tv_ad_dict
# Если флаг regular - то грузим статистику и обновляем справочники
# если start_date(дата начала) НЕ указана, то 
# удаляем из БД - последние 17(сегодня-14-3) дней
# перезаисываем статистику за этот период
# если НЕ указана end_date(дата окончания) - ВКЛЮЧИТЕЛЬНО, то грузим данные до сегодня-3 дня
# получаем статистику по отчету Simple и Buying
get_nat_tv_reports(start_date=start_date, end_date=end_date, flag=flag)

# Обновляем все справочники из ТВ Индекс
update_tv_index_dicts()
# Обновляем основной справочник объявлений
update_nat_tv_ad_dict()

# загружаем в гугл докс Чистка список объяалений с флагом=2
append_ads_to_google()
# Out:
# Скрипт запущен 2025-04-02 10:36:29.046393
# **************************************************
# Забираем из БД НЕ ОБНОВЛЕННЫЙ справочник объявлений
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
#
# Загружаем отчет за период 2025-03-25 - 2025-03-27. Общее количество дней: 3
# **************************************************
#
#
# ==========Загружаем 2025-03-25. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 0cab7ede-2b09-4000-a0e3-217da9b711c9) [= = = = = = = ] время расчета: 0:00:22.362969
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:36:55.627363
# Данные добавлены в БД: test, таблица: nat_tv_buying
# Скрипт отработал 2025-04-02 10:36:55.684834
# Время выполнения задачи: 0:00:00.057471
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (10) [ = = = = ] время расчета: 0:00:21.799436
# Расчет завершен, получаем результат
# Собираем таблицу
# ..........Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:37:45.453306
# Данные добавлены в БД: test, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-04-02 10:37:45.468321
# Время выполнения задачи: 0:00:00.015015
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:37:45.499599
# Данные добавлены в БД: test, таблица: nat_tv_simple
# Скрипт отработал 2025-04-02 10:37:45.986461
# Время выполнения задачи: 0:00:00.486862
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-03-26. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: f4cb5f40-77f2-4876-88ad-d86fcc053c58) [= = = = = = ] время расчета: 0:00:19.310173
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:38:09.453707
# Данные добавлены в БД: test, таблица: nat_tv_buying
# Скрипт отработал 2025-04-02 10:38:09.516226
# Время выполнения задачи: 0:00:00.062519
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (10) [ = = = ] время расчета: 0:00:16.337734
# Расчет завершен, получаем результат
# Собираем таблицу
# ..........Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:38:53.498944
# Данные добавлены в БД: test, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-04-02 10:38:53.516537
# Время выполнения задачи: 0:00:00.017593
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:38:53.530558
# Данные добавлены в БД: test, таблица: nat_tv_simple
# Скрипт отработал 2025-04-02 10:38:53.973164
# Время выполнения задачи: 0:00:00.442606
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-03-27. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: f763ca1b-28d5-4ae3-90f8-99722eb61e7f) [= = = = = = = ] время расчета: 0:00:22.348283
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:39:20.500039
# Данные добавлены в БД: test, таблица: nat_tv_buying
# Скрипт отработал 2025-04-02 10:39:20.572890
# Время выполнения задачи: 0:00:00.072851
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (10) [ = = = = = = ] время расчета: 0:00:32.611700
# Расчет завершен, получаем результат
# Собираем таблицу
# ..........Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:40:20.302512
# Данные добавлены в БД: test, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-04-02 10:40:20.311790
# Время выполнения задачи: 0:00:00.009278
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:40:20.343063
# Данные добавлены в БД: test, таблица: nat_tv_simple
# Скрипт отработал 2025-04-02 10:40:20.764994
# Время выполнения задачи: 0:00:00.421931
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
# **************************************************
#
# **************************************************
# Время окончания работы скрипта 2025-04-02 10:40:20.764994
# Период загрузки 2025-03-25 - 2025-03-27. Общее время работы скрипта: 0:03:51.718601
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 1
# Всего найдено записей: 1
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:40:20.925342
# Данные добавлены в БД: test, таблица: tv_index_advertiser_list_dict
# Скрипт отработал 2025-04-02 10:40:20.937496
# Время выполнения задачи: 0:00:00.012154
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 16
# Всего найдено записей: 16
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:40:21.058060
# Данные добавлены в БД: test, таблица: tv_index_brand_list_dict
# Скрипт отработал 2025-04-02 10:40:21.061116
# Время выполнения задачи: 0:00:00.003056
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 5
# Всего найдено записей: 5
#
# Запрошены записи: 0 - 20
# Всего найдено записей: 20
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:40:21.233260
# Данные добавлены в БД: test, таблица: tv_index_subbrand_list_dict
# Скрипт отработал 2025-04-02 10:40:21.247260
# Время выполнения задачи: 0:00:00.014000
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 27
# Всего найдено записей: 27
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:40:21.373399
# Данные добавлены в БД: test, таблица: tv_index_model_list_dict
# Скрипт отработал 2025-04-02 10:40:21.389025
# Время выполнения задачи: 0:00:00.015626
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 5
# Всего найдено записей: 5
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:40:21.499039
# Данные добавлены в БД: test, таблица: tv_index_article_list2_dict
# Скрипт отработал 2025-04-02 10:40:21.514676
# Время выполнения задачи: 0:00:00.015637
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 15
# Всего найдено записей: 15
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:40:21.631975
# Данные добавлены в БД: test, таблица: tv_index_article_list3_dict
# Скрипт отработал 2025-04-02 10:40:21.646026
# Время выполнения задачи: 0:00:00.014051
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 19
# Всего найдено записей: 19
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:40:21.766851
# Данные добавлены в БД: test, таблица: tv_index_article_list4_dict
# Скрипт отработал 2025-04-02 10:40:21.781477
# Время выполнения задачи: 0:00:00.014626
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 7
# Всего найдено записей: 7
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:40:21.904680
# Данные добавлены в БД: test, таблица: tv_index_audio_slogan_dict
# Скрипт отработал 2025-04-02 10:40:21.917844
# Время выполнения задачи: 0:00:00.013164
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 6
# Всего найдено записей: 6
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:40:22.035572
# Данные добавлены в БД: test, таблица: tv_index_video_slogan_dict
# Скрипт отработал 2025-04-02 10:40:22.050572
# Время выполнения задачи: 0:00:00.015000
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: nat_tv_ad_dict успешно удалена в БД: test
# ##########
# Все ок. Подключились!
# Пустая таблица nat_tv_ad_dict успешно создана в БД test
# Все ок. Подключились!
# Скрипт запущен 2025-04-02 10:40:22.923849
# Данные добавлены в БД: test, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-04-02 10:40:22.949506
# Время выполнения задачи: 0:00:00.025657
# Загрузка завершена. Данные успешно добавлены в БД: test
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Connection established successfully...
# DataFrame exported successfully...
