# %%
import os

from time import sleep
import config

from nat_tv_ratings import get_nat_tv_reports
from create_dicts import update_tv_index_dicts, update_nat_tv_ad_dict
from google_connector import append_ads_to_google


start_date = '2025-03-28' 
end_date = '2025-03-28' #- ВКЛЮЧИТЕЛЬНО

flag='regular' #first / regular
# Out:
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314

# %%
# Если флаг first - создаем набор пустых таблиц-справочников / 
# забираем статистику / заполняем таблицы фактов и справочник nat_tv_ad_dict
# Если флаг regular - то грузим статистику и обновляем справочники
# если start_date(дата начала) НЕ указана, то 
# удаляем из БД - последние 17(сегодня-14-3) дней
# перезаисываем статистику за этот период
# если НЕ указана end_date(дата окончания) - ВКЛЮЧИТЕЛЬНО, то грузим данные до сегодня-3 дня
# получаем статистику по отчету Simple и Buying
get_nat_tv_reports(start_date=start_date, end_date=end_date, flag=flag)
# get_nat_tv_reports(flag=flag)
# Обновляем все справочники из ТВ Индекс
update_tv_index_dicts()
# Обновляем основной справочник объявлений
update_nat_tv_ad_dict()

# загружаем в гугл докс Чистка список объяалений с флагом=2
append_ads_to_google()
# Out:
# Скрипт запущен 2025-04-07 13:08:01.357133
# **************************************************
# Забираем из БД НЕ ОБНОВЛЕННЫЙ справочник объявлений
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
#
# Загружаем отчет за период 2025-03-28 - 2025-03-28. Общее количество дней: 1
# **************************************************
#
#
# ==========Загружаем 2025-03-28. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: a2201f83-45ac-4cdf-93c0-653100bd203f) [= = = = = = = ] время расчета: 0:00:22.419875
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 13:08:30.700416
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-04-07 13:08:30.806251
# Время выполнения задачи: 0:00:00.105835
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (9) [ = = = = = = ] время расчета: 0:00:31.979040
# Расчет завершен, получаем результат
# Собираем таблицу
# .........Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 13:09:27.776653
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-04-07 13:09:27.795125
# Время выполнения задачи: 0:00:00.018472
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 13:09:27.817122
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-04-07 13:09:28.448084
# Время выполнения задачи: 0:00:00.630962
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# **************************************************
# Время окончания работы скрипта 2025-04-07 13:09:28.448084
# Период загрузки 2025-03-28 - 2025-03-28. Общее время работы скрипта: 0:01:27.090951
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 1
# Всего найдено записей: 1
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 13:09:28.709835
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_brand_list_dict
# Скрипт отработал 2025-04-07 13:09:28.730137
# Время выполнения задачи: 0:00:00.020302
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 0
# Всего найдено записей: 0
#
# Запрошены записи: 0 - 2
# Всего найдено записей: 2
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 13:09:28.929724
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_subbrand_list_dict
# Скрипт отработал 2025-04-07 13:09:28.947105
# Время выполнения задачи: 0:00:00.017381
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 3
# Всего найдено записей: 3
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 13:09:29.068312
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_model_list_dict
# Скрипт отработал 2025-04-07 13:09:29.088308
# Время выполнения задачи: 0:00:00.019996
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 1
# Всего найдено записей: 1
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 13:09:29.228178
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_article_list2_dict
# Скрипт отработал 2025-04-07 13:09:29.242181
# Время выполнения задачи: 0:00:00.014003
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 1
# Всего найдено записей: 1
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 13:09:29.365176
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_article_list3_dict
# Скрипт отработал 2025-04-07 13:09:29.376180
# Время выполнения задачи: 0:00:00.011004
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 1
# Всего найдено записей: 1
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 13:09:29.484752
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_article_list4_dict
# Скрипт отработал 2025-04-07 13:09:29.486835
# Время выполнения задачи: 0:00:00.002083
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 1
# Всего найдено записей: 1
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 13:09:29.650759
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_audio_slogan_dict
# Скрипт отработал 2025-04-07 13:09:29.663759
# Время выполнения задачи: 0:00:00.013000
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 1
# Всего найдено записей: 1
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 13:09:29.790759
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_video_slogan_dict
# Скрипт отработал 2025-04-07 13:09:29.812757
# Время выполнения задачи: 0:00:00.021998
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
# C:\Users\o.bogomolov\Desktop\Jupyter_notebook\42_02_mediascope_costs_n_ratings\create_dicts.py:73: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(full_cleaning_link, header=None, usecols=cols_count)
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: nat_tv_ad_dict успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица nat_tv_ad_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-04-07 13:09:37.060288
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-04-07 13:09:37.086287
# Время выполнения задачи: 0:00:00.025999
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Connection established successfully...
# DataFrame exported successfully...
