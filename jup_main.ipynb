# %%
import os

from time import sleep
import config

from nat_tv_ratings import get_nat_tv_reports
from create_dicts_tv_index import update_tv_index_dicts, update_nat_tv_ad_dict
from google_connector import append_ads_to_google


start_date = '2023-01-01' 
end_date = '2023-01-02' #- ВКЛЮЧИТЕЛЬНО

flag='first' #first / regular
# Out:
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314

# %%
# Если флаг first - создаем набор пустых таблиц-справочников / 
# забираем статистику / заполняем таблицы фактов и справочник nat_tv_ad_dict
# Если флаг regular - то грузим статистику и обновляем справочники
# если start_date(дата начала) НЕ указана, то 
# удаляем из БД - последние 17(сегодня-14-3) дней
# перезаисываем статистику за этот период
# если НЕ указана end_date(дата окончания) - ВКЛЮЧИТЕЛЬНО, то грузим данные до сегодня-3 дня
# получаем статистику по отчету Simple и Buying
get_nat_tv_reports(start_date=start_date, end_date=end_date, flag=flag)
# get_nat_tv_reports(flag=flag)
# Обновляем все справочники из ТВ Индекс
update_tv_index_dicts()
# Обновляем основной справочник объявлений
update_nat_tv_ad_dict()

# загружаем в гугл докс Чистка список объяалений с флагом=2
append_ads_to_google()
# Out:
# Скрипт запущен 2025-04-10 08:22:39.644223
# Все ок. Подключились!
# Пустая таблица nat_tv_simple успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица nat_tv_buying успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица nat_tv_ad_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_region_dict успешно создана в БД mediascope_x5
# Запрошены записи: 0 - 28
# Всего найдено записей: 28
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-10 08:22:39.801306
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_region_dict
# Скрипт отработал 2025-04-10 08:22:39.826395
# Время выполнения задачи: 0:00:00.025089
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_tv_net_dict успешно создана в БД mediascope_x5
# Запрошены записи: 0 - 44
# Всего найдено записей: 44
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-10 08:22:39.930438
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_tv_net_dict
# Скрипт отработал 2025-04-10 08:22:39.946143
# Время выполнения задачи: 0:00:00.015705
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_tv_company_dict успешно создана в БД mediascope_x5
# Запрошены записи: 0 - 2418
# Всего найдено записей: 2418
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-10 08:22:40.313854
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_tv_company_dict
# Скрипт отработал 2025-04-10 08:22:40.430490
# Время выполнения задачи: 0:00:00.116636
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_ad_type_dict успешно создана в БД mediascope_x5
# Запрошены записи: 0 - 24
# Всего найдено записей: 24
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-10 08:22:40.547986
# Данные добавлены в БД: mediascope_x5, таблица: tv_index_ad_type_dict
# Скрипт отработал 2025-04-10 08:22:40.555027
# Время выполнения задачи: 0:00:00.007041
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_advertiser_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_brand_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_subbrand_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_model_list_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_article_list2_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_article_list3_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_article_list4_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_audio_slogan_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Пустая таблица tv_index_video_slogan_dict успешно создана в БД mediascope_x5
# **************************************************
# Забираем из БД НЕ ОБНОВЛЕННЫЙ справочник объявлений
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
#
# Загружаем отчет за период 2023-01-01 - 2023-01-02. Общее количество дней: 2
# **************************************************
#
#
# ==========Загружаем 2023-01-01. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 48a86d68-2656-4ab4-8583-4868f468cf4d) [= = = = = = = = ] время расчета: 0:00:25.536399
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-10 08:23:12.751513
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-04-10 08:23:12.773792
# Время выполнения задачи: 0:00:00.022279
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (9) [ = = = = ] время расчета: 0:00:21.418681
# Расчет завершен, получаем результат
# Собираем таблицу
# .........Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-10 08:23:57.156729
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-04-10 08:23:57.170730
# Время выполнения задачи: 0:00:00.014001
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-10 08:23:57.181785
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-04-10 08:23:57.245217
# Время выполнения задачи: 0:00:00.063432
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2023-01-02. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: d28b4700-1a2f-47c7-a531-6df70d7e2d41) [= = = = = = = ] время расчета: 0:00:22.382651
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-10 08:24:26.228324
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_buying
# Скрипт отработал 2025-04-10 08:24:26.306452
# Время выполнения задачи: 0:00:00.078128
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (9) [ = = = = ] время расчета: 0:00:21.364676
# Расчет завершен, получаем результат
# Собираем таблицу
# .........Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-10 08:25:11.212975
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-04-10 08:25:11.228601
# Время выполнения задачи: 0:00:00.015626
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-10 08:25:11.244152
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_simple
# Скрипт отработал 2025-04-10 08:25:11.635652
# Время выполнения задачи: 0:00:00.391500
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# **************************************************
#
# **************************************************
# Время окончания работы скрипта 2025-04-10 08:25:11.636158
# Период загрузки 2023-01-01 - 2023-01-02. Общее время работы скрипта: 0:02:31.991935
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Новых данных для загрузки нет
# C:\Users\o.bogomolov\Desktop\Jupyter_notebook\42_02_mediascope_costs_n_ratings\create_dicts.py:68: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(full_cleaning_link, header=None, usecols=cols_count)
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: nat_tv_ad_dict успешно удалена в БД: mediascope_x5
# ##########
# Все ок. Подключились!
# Пустая таблица nat_tv_ad_dict успешно создана в БД mediascope_x5
# Все ок. Подключились!
# Скрипт запущен 2025-04-10 08:25:18.495135
# Данные добавлены в БД: mediascope_x5, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-04-10 08:25:18.536221
# Время выполнения задачи: 0:00:00.041086
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_x5
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Connection established successfully...
# DataFrame exported successfully...
